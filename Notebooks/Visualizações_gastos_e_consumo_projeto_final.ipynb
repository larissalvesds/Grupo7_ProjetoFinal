# %% [markdown]
# <a href="https://colab.research.google.com/github/meanjos/Grupo7_ProjetoFinal/blob/main/Notebooks/Visualiza%C3%A7%C3%B5es_gastos_e_consumo_projeto_final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Passo 1: Configuração do Ambiente

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Visualizando % de visitantes que pernoitam

# %%
# Dados
perc_pernoitam = 95.86
total_visitantes = 169

# Cálculos
qtd_pernoitam = round(total_visitantes * (perc_pernoitam / 100))
qtd_nao_pernoitam = total_visitantes - qtd_pernoitam

dados_pernoite = {
    "Categoria": ["Pernoitam", "Não pernoitam"],
    "Valor": [perc_pernoitam, 100 - perc_pernoitam],
    "Quantidade": [qtd_pernoitam, qtd_nao_pernoitam]
}

# Cores das fatias
cores = ["#2c3e50", "#a0a0a0"]

# Cores dos rótulos (Texto interno e Porcentagem)
cores_texto = ['white', '#2c3e50']

# Gráfico de pizza
fig, ax = plt.subplots(figsize=(7,7), facecolor="#f8f9fa")
wedges, texts, autotexts = ax.pie(
    dados_pernoite["Valor"],
    labels=[f"{cat}\n({qtd} visitantes)" for cat, qtd in zip(dados_pernoite["Categoria"], dados_pernoite["Quantidade"])],
    autopct='%1.1f%%',
    colors=cores,
    startangle=140
)

# Atualiza a cor dos rótulos (rótulos de texto e porcentagens)
for i, (text, autotext) in enumerate(zip(texts, autotexts)):
    text.set_color(cores_texto[i])
    autotext.set_color(cores_texto[i])
    text.set_fontsize(11)
    autotext.set_fontsize(11)

# Estilo do título
plt.title("% de Visitantes que Pernoitaram", fontsize=14, fontweight="bold", color="#2c3e50", pad=20)

# Configurações do gráfico
plt.axis('equal')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Média de pernoites

# %%
#Dados
media_pernoites = 4.6863905325443795

# Card visual
fig, ax = plt.subplots(figsize=(6,3), facecolor="#f8f9fa")
ax.text(0.5, 0.6, f"{media_pernoites:.2f}", fontsize=48, color="#2c3e50", ha='center', va='center', fontweight='bold')
ax.text(0.5, 0.25, "Média de Pernoites por Visitante", fontsize=13, color="#555", ha='center', va='center')

# Remove eixos pra ficar limpo
ax.axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Médias de gastos dos visitantes

# %%
#Dados
dados_gastos = {
    "Gasto": [
        "Hospedagem", "Atrativos", "Alimentação", "Transporte",
        "Fantasia", "Compras", "Ingressos", "Outros"
    ],
    "Média": [
        346.96,   # Hospedagem
        358.21,   # Atrativos
        540.71,   # Alimentação
        169.12,   # Transporte
        69.51,    # Fantasia
        129.57,   # Compras
        71.20,    # Ingressos
        14.09     # Outros
    ]
}

df_gastos = pd.DataFrame(dados_gastos)

# Exibir tabela
print("Médias de Gastos dos Visitantes:")
display(df_gastos)

# Gráfico de barras

cores = ["#2c3e50", "#a0a0a0"]  # azul escuro e cinza médio
# Alternando cores para cada barra
barra_cores = [cores[i % len(cores)] for i in range(len(df_gastos))]

plt.figure(figsize=(10,6))
plt.bar(df_gastos["Gasto"], df_gastos["Média"], color=barra_cores)
plt.title("Médias de Gastos dos Visitantes", fontsize=14, fontweight="bold", color="#2c3e50")
plt.xlabel("Categoria", fontsize=12, color="#2c3e50")
plt.ylabel("Valor Médio (R$)", fontsize=12, color="#2c3e50")
plt.xticks(rotation=45, fontsize=10, color="#2c3e50")
plt.yticks(fontsize=10, color="#2c3e50")
plt.grid(axis='y', linestyle='--', alpha=0.7)  # linhas de grade para facilitar leitura
plt.tight_layout()
plt.show()
# Out:
# Médias de Gastos dos Visitantes:
#          Gasto   Média
# 0   Hospedagem  346.96
# 1    Atrativos  358.21
# 2  Alimentação  540.71
# 3   Transporte  169.12
# 4     Fantasia   69.51
# 5      Compras  129.57
# 6    Ingressos   71.20
# 7       Outros   14.09

# %% [markdown]
# ### Médias de gastos dos Moradores

# %%
# Médias de gastos dos moradores
dados_moradores = {
    "Gasto": [
        "Hospedagem", "Atrativos", "Alimentação", "Transporte",
        "Fantasia", "Compras", "Ingressos", "Outros"
    ],
    "Média": [
        np.nan,   # Hospedagem
        np.nan,   # Atrativos
        271.70,   # Alimentação
        89.29,    # Transporte
        49.04,    # Fantasia
        67.89,    # Compras
        21.25,    # Ingressos
        6.98      # Outros
    ]
}

df_moradores = pd.DataFrame(dados_moradores)

# Exibir tabela
print("Médias de Gastos dos Moradores:")
display(df_moradores)


# Gráfico de barras
cores = ["#2c3e50", "#a0a0a0"]  # azul escuro e cinza médio
barra_cores = [cores[i % len(cores)] for i in range(len(df_moradores))]

plt.figure(figsize=(10,6))
plt.bar(df_moradores["Gasto"], df_moradores["Média"], color=barra_cores)
plt.title("Médias de Gastos dos Moradores", fontsize=14, fontweight="bold", color="#2c3e50")
plt.xlabel("Categoria", fontsize=12, color="#2c3e50")
plt.ylabel("Valor Médio (R$)", fontsize=12, color="#2c3e50")
plt.xticks(rotation=45, fontsize=10, color="#2c3e50")
plt.yticks(fontsize=10, color="#2c3e50")
plt.grid(axis='y', linestyle='--', alpha=0.7)  # linhas de grade para facilitar leitura
plt.tight_layout()
plt.show()
# Out:
# Médias de Gastos dos Moradores:
#          Gasto   Média
# 0   Hospedagem     NaN
# 1    Atrativos     NaN
# 2  Alimentação  271.70
# 3   Transporte   89.29
# 4     Fantasia   49.04
# 5      Compras   67.89
# 6    Ingressos   21.25
# 7       Outros    6.98

# %% [markdown]
# ### Top 3 meios de hospedagem dos visitantes

# %%
# Dados
dados_hosp = {
    "Hospedagem": ["Casa de Amigos/Parentes", "Hotels/Pousadas", "Casa própria"],
    "Total": [112, 21, 12]
}

df_hosp = pd.DataFrame(dados_hosp)

# Exibir tabela
print("Top 3 meios de hospedagem dos visitantes:")
display(df_hosp)

custom_colors = ['#1F496B', '#B0B0B0', '#666666']

plt.figure(figsize=(7,7))

wedges, texts, autotexts = plt.pie(
    df_hosp["Total"],
    autopct='%1.1f%%',
    startangle=140,
    pctdistance=0.65,
    colors=custom_colors,
    textprops={'color': 'white'}
)

plt.title("Top 3 Meios de Hospedagem", fontsize=14, fontweight="bold", color="#2c3e50")

plt.legend(
    wedges,
    df_hosp["Hospedagem"],
    title="Tipo de Hospedagem",
    loc="center left",
    bbox_to_anchor=(1, 0, 0.5, 1)
)

plt.tight_layout()
plt.show()
# Out:
# Top 3 meios de hospedagem dos visitantes:
#                 Hospedagem  Total
# 0  Casa de Amigos/Parentes    112
# 1          Hotels/Pousadas     21
# 2             Casa própria     12

# %% [markdown]
# ### Top 3 meios de transporte dos visitantes

# %%
#Dados
dados_transp = {
    "Transporte": ["Aplicativos (Uber/99/InDrive)", "Onibus coletivo", "Veiculo Proprio"],
    "Total": [420, 266, 207]
}


df_transp = pd.DataFrame(dados_transp)

# Exibir tabela
print("Top 3 Transportes para Chegada na Cidade (Visitantes):")
display(df_transp)

# Paleta de cores
cores = ["#2c3e50", "#a0a0a0"]
barra_cores = [cores[i % len(cores)] for i in range(len(df_transp))]

plt.figure(figsize=(10,6))
plt.bar(df_transp["Transporte"], df_transp["Total"], color=barra_cores)
plt.title("Top 3 Meios de Transporte")
plt.xlabel("Transporte")
plt.ylabel("Quantidade")
plt.xticks(rotation=30)
plt.tight_layout()
plt.show()
# Out:
# Top 3 Transportes para Chegada na Cidade (Visitantes):
#                       Transporte  Total
# 0  Aplicativos (Uber/99/InDrive)    420
# 1                Onibus coletivo    266
# 2                Veiculo Proprio    207

# %% [markdown]
# ### **Análise de resultados e insights estratégicos**
#
#
# 🎭 1. Perfil e Comportamento dos Visitantes
#
# - Alta taxa de pernoite: média de pernoite >4 → oportunidade de fomentar pacotes turísticos (hotéis + experiências culturais).
#
# - Meios de hospedagem: predominância de casa de amigos/parentes → sinal de que a rede hoteleira não está sendo totalmente aproveitada. Ação: incentivar hotéis e Airbnbs com promoções ou parcerias oficiais.
#
# 🍹 2. Gastos dos Visitantes
#
# Categorias que mais puxam os gastos: Alimentação, Atrativos e Hospedagem.
#
#  - A Alimentação é o principal gasto, indicando a importância crítica da infraestrutura de food service. Atrativos e Hospedagem em seguida, confirmando que o público investe em experiências, lazer e estadia na cidade.
#
# --> Ação: Reforçar a fiscalização e o licenciamento de ambulantes e restaurantes e promover pacotes turísticos (Atrativos + Hospedagem) para consolidar a receita.
#
# - Transporte e Compras mantêm peso intermediário.
#
# --> Ação: Ampliar as rotas de transporte, fortalecer parcerias com apps de corridas e ampliar as rotas de ônibus durante o evento, além de incentivar feiras de artesanato e produtos temáticos em locais de fácil acesso.
#
# - Ingressos e Fantasias com os menores valores entre as despesas relevantes.
#
#   Contexto: Ingressos e Fantasias têm gastos menores, indicando que o foco pode estar mais na folia de rua gratuita e menos em eventos fechados de alto custo ou na compra de fantasias caras.
#
# --> Ação: Avaliar a precificação de eventos pagos e/ou promover eventos de acesso mais fácil para o público.
#
#
# 🚎 3. Transporte e Mobilidade
#
# - Forte uso de aplicativos (Uber/99) → mostra conveniência, mas pode gerar trânsito e encarecimento em horários de pico.
#
# --> Ação: prefeitura poderia reforçar transporte coletivo com rotas exclusivas para blocos e pontos de embarque organizados, linhas de ônibus 24h, pontos de apoio para táxis/Uber, incentivo ao uso de bikes e patinetes.
